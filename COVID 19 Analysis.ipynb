# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading The Dataset

# %%
df = pd.read_csv('covid_19_india.csv')
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  30-01-2020  6:00 PM               Kerala
# 1          2  31-01-2020  6:00 PM               Kerala
# 2          3  01-02-2020  6:00 PM               Kerala
# 3          4  02-02-2020  6:00 PM               Kerala
# 4          5  03-02-2020  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  11-08-2021  8:00 AM            Telangana
# 18106  18107  11-08-2021  8:00 AM              Tripura
# 18107  18108  11-08-2021  8:00 AM          Uttarakhand
# 18108  18109  11-08-2021  8:00 AM        Uttar Pradesh
# 18109  18110  11-08-2021  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# # isnull()

# %%
df.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %% [markdown]
# # Fetching the Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       18110 non-null  int64
#  1   Date                      18110 non-null  object
#  2   Time                      18110 non-null  object
#  3   State/UnionTerritory      18110 non-null  object
#  4   ConfirmedIndianNational   18110 non-null  object
#  5   ConfirmedForeignNational  18110 non-null  object
#  6   Cured                     18110 non-null  int64
#  7   Deaths                    18110 non-null  int64
#  8   Confirmed                 18110 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# # Changing the Datatypes

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month Name'] = df['Date'].dt.month_name()
df
# Out:
# C:\Users\91821\AppData\Local\Temp\ipykernel_9548\4191723405.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])
#          Sno       Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00 PM               Kerala                       1
# 1          2 2020-01-31  6:00 PM               Kerala                       1
# 2          3 2020-02-01  6:00 PM               Kerala                       2
# 3          4 2020-02-02  6:00 PM               Kerala                       3
# 4          5 2020-02-03  6:00 PM               Kerala                       3
# ...      ...        ...      ...                  ...                     ...
# 18105  18106 2021-08-11  8:00 AM            Telangana                       -
# 18106  18107 2021-08-11  8:00 AM              Tripura                       -
# ...

# %%
df['Time'] = df['Time'].str.replace('PM', '')
df['Time'] = df['Time'].str.replace('AM', '')
df
# Out:
#          Sno       Date   Time State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30  6:00                Kerala                       1
# 1          2 2020-01-31  6:00                Kerala                       1
# 2          3 2020-02-01  6:00                Kerala                       2
# 3          4 2020-02-02  6:00                Kerala                       3
# 4          5 2020-02-03  6:00                Kerala                       3
# ...      ...        ...    ...                  ...                     ...
# 18105  18106 2021-08-11  8:00             Telangana                       -
# 18106  18107 2021-08-11  8:00               Tripura                       -
# 18107  18108 2021-08-11  8:00           Uttarakhand                       -
# 18108  18109 2021-08-11  8:00         Uttar Pradesh                       -
# 18109  18110 2021-08-11  8:00           West Bengal                       -
#
# ...

# %%
df = df.drop(columns = 'Time')
df
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 18105  18106 2021-08-11            Telangana                       -
# 18106  18107 2021-08-11              Tripura                       -
# 18107  18108 2021-08-11          Uttarakhand                       -
# 18108  18109 2021-08-11        Uttar Pradesh                       -
# 18109  18110 2021-08-11          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %% [markdown]
# # Value Counts

# %%
sdf = df['State/UnionTerritory'].value_counts().head(10)
sdf = sdf.reset_index()
sdf
# Out:
#   State/UnionTerritory  count
# 0               Kerala    560
# 1                Delhi    528
# 2            Rajasthan    527
# 3        Uttar Pradesh    526
# 4              Haryana    526
# 5               Ladakh    523
# 6           Tamil Nadu    523
# 7               Punjab    521
# 8    Jammu and Kashmir    521
# 9          Maharashtra    520

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(sdf['State/UnionTerritory'], sdf['count'])
plt.xlabel('State/Union Territory')
plt.ylabel('Count of Cases in State')
plt.savefig('COVID CASES IN STATES.png', format='png')

# %%
df
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 18105  18106 2021-08-11            Telangana                       -
# 18106  18107 2021-08-11              Tripura                       -
# 18107  18108 2021-08-11          Uttarakhand                       -
# 18108  18109 2021-08-11        Uttar Pradesh                       -
# 18109  18110 2021-08-11          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %%
mdf = df.groupby('Month Name').agg(ConfirmedDeaths = ('Deaths', 'sum'))
mdf = mdf.reset_index().sort_values(by='ConfirmedDeaths', ascending = False)
mdf
# Out:
#    Month Name  ConfirmedDeaths
# 5        July         13575039
# 6        June         11475067
# 8         May          8480751
# 1      August          6247991
# 0       April          5353568
# 7       March          4935455
# 4     January          4709167
# 2    December          4457379
# 3    February          4359434
# 9    November          3894165
# 10    October          3457615
# 11  September          2443374

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(mdf['Month Name'], mdf['ConfirmedDeaths'])
plt.title('Confirmed Deaths in Month')
plt.xlabel('Month Name')
plt.ylabel('Confirmed Deaths in Month')
plt.savefig('COVID DEATHS IN MONTH.png', format='png')

# %%
df
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 18105  18106 2021-08-11            Telangana                       -
# 18106  18107 2021-08-11              Tripura                       -
# 18107  18108 2021-08-11          Uttarakhand                       -
# 18108  18109 2021-08-11        Uttar Pradesh                       -
# 18109  18110 2021-08-11          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %%
cdf = df.groupby('Month Name').agg(ConfirmedCases = ('Confirmed', 'sum'))
cdf = cdf.reset_index().sort_values(by='ConfirmedCases', ascending = False)
cdf
# Out:
#    Month Name  ConfirmedCases
# 5        July       993362865
# 6        June       895231838
# 8         May       754865720
# 0       April       441083113
# 1      August       431100375
# 7       March       356315303
# 4     January       326469749
# 2    December       307177353
# 3    February       305631889
# 9    November       264556412
# 10    October       226770312
# 11  September       149113758

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(cdf['Month Name'], cdf['ConfirmedCases'])
plt.title('Confirmed Cases in Month')
plt.xlabel('Month Name')
plt.ylabel('Confirmed Cases in Month')
plt.savefig('COVID CONFIRMED CASES IN MONTH.png', format='png')

# %%
df
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 18105  18106 2021-08-11            Telangana                       -
# 18106  18107 2021-08-11              Tripura                       -
# 18107  18108 2021-08-11          Uttarakhand                       -
# 18108  18109 2021-08-11        Uttar Pradesh                       -
# 18109  18110 2021-08-11          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %%
tdf = df.groupby('Month Name').agg(CuredCases = ('Cured', 'sum'))
tdf = tdf.reset_index().sort_values(by='CuredCases', ascending = False)
tdf
# Out:
#    Month Name  CuredCases
# 5        July   955269787
# 6        June   848822379
# 8         May   646240106
# 1      August   399775889
# 0       April   385065633
# 7       March   342611205
# 4     January   315332019
# 3    February   297133802
# 2    December   292244085
# 9    November   246213201
# 10    October   198824412
# 11  September   118592934

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(tdf['Month Name'], tdf['CuredCases'])
plt.title('Cured Cases in Month')
plt.xlabel('Month Name')
plt.ylabel('Cured Cases in Month')
plt.savefig('COVID CURED CASES IN MONTH.png', format='png')

# %%
df
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 18105  18106 2021-08-11            Telangana                       -
# 18106  18107 2021-08-11              Tripura                       -
# 18107  18108 2021-08-11          Uttarakhand                       -
# 18108  18109 2021-08-11        Uttar Pradesh                       -
# 18109  18110 2021-08-11          West Bengal                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %%
kdf = df.groupby('State/UnionTerritory').agg(TotalDeath = ('Deaths', 'sum'))
kdf = kdf.reset_index().sort_values(by='TotalDeath', ascending=False).head(10)
kdf
# Out:
#    State/UnionTerritory  TotalDeath
# 27          Maharashtra    23737432
# 21            Karnataka     6053762
# 38           Tamil Nadu     5916658
# 12                Delhi     4943294
# 43        Uttar Pradesh     4143450
# 45          West Bengal     3846989
# 1        Andhra Pradesh     2939367
# 35               Punjab     2785594
# 14              Gujarat     2219448
# 8          Chhattisgarh     2063920

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(kdf['State/UnionTerritory'], kdf['TotalDeath'])
plt.title('Death Cases in State')
plt.xlabel('State/Union Territory')
plt.ylabel('Total Deaths in States')
plt.savefig('COVID DEATH CASES IN STATES.png', format='png')

# %% [markdown]
# # Kerala Study

# %%
udf = df.loc[df['State/UnionTerritory'] == 'Kerala']
udf
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 0          1 2020-01-30               Kerala                       1
# 1          2 2020-01-31               Kerala                       1
# 2          3 2020-02-01               Kerala                       2
# 3          4 2020-02-02               Kerala                       3
# 4          5 2020-02-03               Kerala                       3
# ...      ...        ...                  ...                     ...
# 17946  17947 2021-08-07               Kerala                       -
# 17982  17983 2021-08-08               Kerala                       -
# 18018  18019 2021-08-09               Kerala                       -
# 18054  18055 2021-08-10               Kerala                       -
# 18090  18091 2021-08-11               Kerala                       -
#
#       ConfirmedForeignNational    Cured  Deaths  Confirmed Month Name
# ...

# %%
idf = udf.groupby('Month Name').agg(TotalDeathCases = ('Deaths', 'sum'))
idf = idf.reset_index().sort_values(by='TotalDeathCases', ascending=False)
idf
# Out:
#    Month Name  TotalDeathCases
# 5        July           465895
# 6        June           336646
# 8         May           203461
# 1      August           196036
# 0       April           146410
# 7       March           136589
# 3    February           111157
# 4     January           105654
# 2    December            82588
# 9    November            55658
# 10    October            33918
# 11  September            14165

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(idf['Month Name'], idf['TotalDeathCases'])
plt.title('Death Cases in Kerala')
plt.xlabel('Month Names')
plt.ylabel('Total Deaths in Kerala')
plt.savefig('COVID DEATH CASES IN KERALA.png', format='png')

# %% [markdown]
# # Confirmed Cases in Kerala

# %%
rdf = udf.groupby('Month Name').agg(TotalConfirmedCases = ('Confirmed', 'sum'))
rdf = rdf.reset_index().sort_values(by='TotalConfirmedCases', ascending=False)
rdf
# Out:
#    Month Name  TotalConfirmedCases
# 5        July             97261513
# 6        June             82160691
# 8         May             64585178
# 1      August             39793646
# 0       April             37315759
# 7       March             33852823
# 3    February             27930718
# 4     January             26008756
# 2    December             21071257
# 9    November             15591120
# 10    October              9763929
# 11  September              3570633

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(rdf['Month Name'], rdf['TotalConfirmedCases'])
plt.title('Confirmed Cases in Kerala')
plt.xlabel('Month Names')
plt.ylabel('Total Confirmed Cases in Kerala')
plt.savefig('COVID CONFIRMED CASES IN KERALA.png', format='png')

# %% [markdown]
# # Bihar Study

# %%
bdf = df.loc[df['State/UnionTerritory'] == 'Bihar']
bdf
# Out:
#          Sno       Date State/UnionTerritory ConfirmedIndianNational  \
# 271      272 2020-03-22                Bihar                       2
# 294      295 2020-03-23                Bihar                       2
# 317      318 2020-03-24                Bihar                       3
# 341      342 2020-03-25                Bihar                       4
# 367      368 2020-03-26                Bihar                       6
# ...      ...        ...                  ...                     ...
# 17934  17935 2021-08-07                Bihar                       -
# 17970  17971 2021-08-08                Bihar                       -
# 18006  18007 2021-08-09                Bihar                       -
# 18042  18043 2021-08-10                Bihar                       -
# 18078  18079 2021-08-11                Bihar                       -
#
#       ConfirmedForeignNational   Cured  Deaths  Confirmed Month Name
# 271                          0       0       1          2      March
# ...

# %%
odf = bdf.groupby('Month Name').agg(TotalCuredCases = ('Cured', 'sum'))
odf = odf.reset_index().sort_values(by = 'TotalCuredCases', ascending=False)
odf
# Out:
#    Month Name  TotalCuredCases
# 5        July         22589630
# 6        June         19802049
# 8         May         16901183
# 1      August         10096465
# 0       April          8483953
# 7       March          8099020
# 4     January          7800177
# 2    December          7333313
# 3    February          7257708
# 9    November          6554762
# 10    October          5856306
# 11  September          4348336

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(odf['Month Name'], odf['TotalCuredCases'])
plt.title('Cured Cases in Bihar')
plt.xlabel('Month Names')
plt.ylabel('Total Cured Cases in Bihar')
plt.savefig('COVID CURED CASES IN BIHAR.png', format='png')

# %%
ydf = udf.groupby('Month Name').agg(TotalCuredCases = ('Cured', 'sum'))
ydf = ydf.reset_index().sort_values(by='TotalCuredCases', ascending=False)
ydf
# Out:
#    Month Name  TotalCuredCases
# 5        July         92823825
# 6        June         77870015
# 8         May         53709432
# 1      August         37196015
# 0       April         34171565
# 7       March         32704468
# 3    February         26076321
# 4     January         23797725
# 2    December         19089246
# 9    November         13288127
# 10    October          6918689
# 11  September          2528807

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize = (18, 5))
plt.bar(ydf['Month Name'], ydf['TotalCuredCases'])
plt.title('Cured Cases in Kerala')
plt.xlabel('Month Names')
plt.ylabel('Total Cured Cases in Kerala')
plt.savefig('COVID CURED CASES IN KERALA.png', format='png')
